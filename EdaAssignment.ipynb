# %% [markdown]
# <a href="https://colab.research.google.com/github/Guptachetan08/Thapar-Summer-School-Combined/blob/main/EdaAssignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 1. Importing the required libraries for EDA

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
#%matplotlib inline
#sns.set(color_codes=True)

# %% [markdown]
# ## 2. Loading the data into the data frame.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv("/content/drive/MyDrive/edaAssignment/TetuanCityPowerConsumption.csv")
df.head()
# Out:
#         DateTime  Temperature  Humidity  Wind Speed  general diffuse flows  \
# 0  1/1/2017 0:00        6.559      73.8       0.083                  0.051
# 1  1/1/2017 0:10        6.414      74.5       0.083                  0.070
# 2  1/1/2017 0:20        6.313      74.5       0.080                  0.062
# 3  1/1/2017 0:30        6.121      75.0       0.083                  0.091
# 4  1/1/2017 0:40        5.921      75.7       0.081                  0.048
#
#    diffuse flows  Zone 1 Power Consumption  Zone 2  Power Consumption  \
# 0          0.119               34055.69620                16128.87538
# 1          0.085               29814.68354                19375.07599
# 2          0.100               29128.10127                19006.68693
# 3          0.096               28228.86076                18361.09422
# 4          0.085               27335.69620                17872.34043
#
#    Zone 3  Power Consumption
# 0                20240.96386
# 1                20131.08434
# ...

# %% [markdown]
# ## 3. Checking the types of data

# %%
df.dtypes
# Out:
# DateTime                      object
# Temperature                  float64
# Humidity                     float64
# Wind Speed                   float64
# general diffuse flows        float64
# diffuse flows                float64
# Zone 1 Power Consumption     float64
# Zone 2  Power Consumption    float64
# Zone 3  Power Consumption    float64
# dtype: object

# %% [markdown]
# ## 4. Dropping irrelevant columns

# %%
pd.unique(df['Humidity'])
# Out:
# array([73.8 , 74.5 , 75.  , ..., 41.96, 41.22, 45.89])

# %%
# df = df.drop([''], axis=1)
df.head(5)
# Out:
#         DateTime  Temperature  Humidity  Wind Speed  general diffuse flows  \
# 0  1/1/2017 0:00        6.559      73.8       0.083                  0.051
# 1  1/1/2017 0:10        6.414      74.5       0.083                  0.070
# 2  1/1/2017 0:20        6.313      74.5       0.080                  0.062
# 3  1/1/2017 0:30        6.121      75.0       0.083                  0.091
# 4  1/1/2017 0:40        5.921      75.7       0.081                  0.048
#
#    diffuse flows  Zone 1 Power Consumption  Zone 2  Power Consumption  \
# 0          0.119               34055.69620                16128.87538
# 1          0.085               29814.68354                19375.07599
# 2          0.100               29128.10127                19006.68693
# 3          0.096               28228.86076                18361.09422
# 4          0.085               27335.69620                17872.34043
#
#    Zone 3  Power Consumption
# 0                20240.96386
# 1                20131.08434
# ...

# %% [markdown]
# ## 5. Renaming the columns

# %%
df = df.rename(columns={"Zone 1 Power Consumption": "Zone1", "Zone 2  Power Consumption": "Zone2", "Zone 3  Power Consumption": "Zone3"})

# %%
df.head(5)
# Out:
#         DateTime  Temperature  Humidity  Wind Speed  general diffuse flows  \
# 0  1/1/2017 0:00        6.559      73.8       0.083                  0.051
# 1  1/1/2017 0:10        6.414      74.5       0.083                  0.070
# 2  1/1/2017 0:20        6.313      74.5       0.080                  0.062
# 3  1/1/2017 0:30        6.121      75.0       0.083                  0.091
# 4  1/1/2017 0:40        5.921      75.7       0.081                  0.048
#
#    diffuse flows        Zone1        Zone2        Zone3
# 0          0.119  34055.69620  16128.87538  20240.96386
# 1          0.085  29814.68354  19375.07599  20131.08434
# 2          0.100  29128.10127  19006.68693  19668.43373
# 3          0.096  28228.86076  18361.09422  18899.27711
# 4          0.085  27335.69620  17872.34043  18442.40964

# %%
from matplotlib import pyplot as plt
_df_0['Temperature'].plot(kind='hist', bins=20, title='Temperature')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
_df_0['Temperature'].plot(kind='hist', bins=20, title='Temperature')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
df.shape
# Out:
# (52416, 9)

# %% [markdown]
# ## 6. Dropping the duplicate rows

# %%
duplicate_rows_df = df[df.duplicated()]
print("number of duplicate rows: ", duplicate_rows_df.shape)
# Out:
# number of duplicate rows:  (0, 9)

# %%
df.count()      # Used to count the number of rows
# Out:
# DateTime                     52416
# Temperature                  52416
# Humidity                     52416
# Wind Speed                   52416
# general diffuse flows        52416
# diffuse flows                52416
# Zone1                        52416
# Zone 2  Power Consumption    52416
# Zone 3  Power Consumption    52416
# dtype: int64

# %%
df = df.drop_duplicates()
df.head()
# Out:
#         DateTime  Temperature  Humidity  Wind Speed  general diffuse flows  \
# 0  1/1/2017 0:00        6.559      73.8       0.083                  0.051
# 1  1/1/2017 0:10        6.414      74.5       0.083                  0.070
# 2  1/1/2017 0:20        6.313      74.5       0.080                  0.062
# 3  1/1/2017 0:30        6.121      75.0       0.083                  0.091
# 4  1/1/2017 0:40        5.921      75.7       0.081                  0.048
#
#    diffuse flows        Zone1  Zone 2  Power Consumption  \
# 0          0.119  34055.69620                16128.87538
# 1          0.085  29814.68354                19375.07599
# 2          0.100  29128.10127                19006.68693
# 3          0.096  28228.86076                18361.09422
# 4          0.085  27335.69620                17872.34043
#
#    Zone 3  Power Consumption
# 0                20240.96386
# 1                20131.08434
# 2                19668.43373
# 3                18899.27711
# ...

# %% [markdown]
# ## 7. Dropping the missing or null values.

# %%
print(df.isnull().sum())
# Out:
# DateTime                     0
# Temperature                  0
# Humidity                     0
# Wind Speed                   0
# general diffuse flows        0
# diffuse flows                0
# Zone1                        0
# Zone 2  Power Consumption    0
# Zone 3  Power Consumption    0
# dtype: int64

# %%
df = df.dropna()    # Dropping the missing values.
df.count()
# Out:
# DateTime                     52416
# Temperature                  52416
# Humidity                     52416
# Wind Speed                   52416
# general diffuse flows        52416
# diffuse flows                52416
# Zone1                        52416
# Zone 2  Power Consumption    52416
# Zone 3  Power Consumption    52416
# dtype: int64

# %%
df.head()
# Out:
#         DateTime  Temperature  Humidity  Wind Speed  general diffuse flows  \
# 0  1/1/2017 0:00        6.559      73.8       0.083                  0.051
# 1  1/1/2017 0:10        6.414      74.5       0.083                  0.070
# 2  1/1/2017 0:20        6.313      74.5       0.080                  0.062
# 3  1/1/2017 0:30        6.121      75.0       0.083                  0.091
# 4  1/1/2017 0:40        5.921      75.7       0.081                  0.048
#
#    diffuse flows        Zone1        Zone2        Zone3
# 0          0.119  34055.69620  16128.87538  20240.96386
# 1          0.085  29814.68354  19375.07599  20131.08434
# 2          0.100  29128.10127  19006.68693  19668.43373
# 3          0.096  28228.86076  18361.09422  18899.27711
# 4          0.085  27335.69620  17872.34043  18442.40964

# %% [markdown]
# ## 8. Detecting Outliers

# %%
sns.boxplot(x=df['Zone1'])
# Out:
# <Axes: xlabel='Zone1'>

# %%
sns.boxplot(x=df['Zone2'])
# Out:
# <Axes: xlabel='Zone2'>

# %%
sns.boxplot(x=df['Zone3'])
# Out:
# <Axes: xlabel='Zone3'>

# %%
sns.boxplot(x=df['Wind Speed'])
# Out:
# <Axes: xlabel='Wind Speed'>

# %%
sns.boxplot(x=df['Humidity'])
# Out:
# <Axes: xlabel='Humidity'>

# %% [markdown]
# ## 9. Plot different features against one another

# %%
plt.figure(figsize=(10,6))
sns.histplot(df['Temperature'])
# Out:
# <Axes: xlabel='Temperature', ylabel='Count'>

# %%
plt.figure(figsize=(10,6))
sns.histplot(df['Humidity'])
# Out:
# <Axes: xlabel='Humidity', ylabel='Count'>

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x=df['Temperature'], y=df['Zone2']) # variables can be changed between different combinations of zones, humidity and temperature
# Out:
# <Axes: xlabel='Temperature', ylabel='Zone2'>

# %%
plt.figure(figsize=(10,6))
sns.lineplot(x=df['Temperature'],y=df['Zone1'])
# Out:
# <Axes: xlabel='Temperature', ylabel='Zone1'>

# %%
df.describe()
# Out:
#         Temperature      Humidity    Wind Speed  general diffuse flows  \
# count  52416.000000  52416.000000  52416.000000           52416.000000
# mean      18.810024     68.259518      1.959489             182.696614
# std        5.815476     15.551177      2.348862             264.400960
# min        3.247000     11.340000      0.050000               0.004000
# 25%       14.410000     58.310000      0.078000               0.062000
# 50%       18.780000     69.860000      0.086000               5.035500
# 75%       22.890000     81.400000      4.915000             319.600000
# max       40.010000     94.800000      6.483000            1163.000000
#
#        diffuse flows         Zone1         Zone2         Zone3
# count   52416.000000  52416.000000  52416.000000  52416.000000
# mean       75.028022  32344.970564  21042.509082  17835.406218
# std       124.210949   7130.562564   5201.465892   6622.165099
# min         0.011000  13895.696200   8560.081466   5935.174070
# ...

# %%
plt.figure(figsize=(10,5))
c= df.corr(numeric_only=True)
sns.heatmap(c,annot=True)
# Out:
# <Axes: >
